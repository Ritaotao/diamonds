# %%
import os
import numpy as np
import pandas as pd

# %%
path = './data/diamonds_20200620.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    carat clarity color culet    cut    date dateSet  depth  \
# 0   1.50     SI1     H  None  Ideal  Jun 10  Jun 11   59.9
# 1   1.51     VS2     H  None  Ideal  Jun 22  Jun 23   62.7
# 2   1.05    VVS1     E  None  Ideal   Jun 9  Jun 10   61.7
# 3   1.35     VS2     G  None  Ideal  Jun 15  Jun 16   62.1
# 4   1.40    VVS2     H  None  Ideal  Jul 15  Jul 16   62.7
#
#                  detailsPageUrl fluorescence          ...           shapeCode  \
# 0  ./diamond-details/LD13542671         None          ...                  RD
# 1  ./diamond-details/LD13873802         None          ...                  RD
# 2  ./diamond-details/LD07418539       Medium          ...                  RD
# 3  ./diamond-details/LD09783992         None          ...                  RD
# 4  ./diamond-details/LD13516656         None          ...                  RD
#
#   shapeName        skus   sold strikethroughPrice   symmetry  table  \
# 0     Round  LD13542671  False                NaN  Excellent   60.0
# 1     Round  LD13873802  False                NaN  Excellent   57.0
# 2     Round  LD07418539  False                NaN  Excellent   57.0
# 3     Round  LD09783992  False                NaN  Excellent   58.0
# 4     Round  LD13516656  False                NaN  Excellent   58.0
#
#                                          v360BaseUrl  \
# 0  https://bluenile.v360.in/51/imaged/gia-2205795...
# 1                                                NaN
# 2  https://bluenile.v360.in/1/imaged/gia-12351614...
# 3  https://bluenile.v360.in/67/imaged/gia-7278979...
# 4  https://bluenile.v360.in/50/imaged/gia-2346880...
#
#                                visualizationImageUrl  willArriveForHoliday
# 0  https://bnsec.bluenile.com/bnsecure/diamondvis...                 False
# 1                                                NaN                 False
# 2  https://bnsec.bluenile.com/bnsecure/diamondvis...                 False
# 3  https://bnsec.bluenile.com/bnsecure/diamondvis...                 False
# 4  https://bnsec.bluenile.com/bnsecure/diamondvis...                 False
#
# [5 rows x 30 columns]

# %%
df.loc[12880, :]
# Out:
# carat                                                                 1.82
# clarity                                                               VVS2
# color                                                                    D
# culet                                                                 None
# cut                                                                  Ideal
# date                                                                Jun 15
# dateSet                                                             Jun 16
# depth                                                                 60.8
# detailsPageUrl                                ./diamond-details/LD13826785
# fluorescence                                                          None
# hasVisualization                                                      True
# id                                                              LD13826785
# imageUrl                                                               NaN
# lxwRatio                                                                 1
# measurements                                         7.93 x 7.90 x 4.81 mm
# polish                                                           Excellent
# price                                                                24695
# pricePerCarat                                                        13569
# quickShip                                                            False
# sellingIndex                                                      0.187747
# shapeCode                                                               RD
# shapeName                                                            Round
# skus                                                            LD13826785
# sold                                                                 False
# strikethroughPrice                                                     NaN
# symmetry                                                         Excellent
# table                                                                   56
# v360BaseUrl              https://bluenile.v360.in/17/imaged/gia-2346856...
# visualizationImageUrl    https://bnsec.bluenile.com/bnsecure/diamondvis...
# willArriveForHoliday                                                 False
# Name: 12880, dtype: object

# %%
# Diamond fluorescence itself is a debated topic, see https://www.leibish.com/diamond-fluorescence-article-245
# [TODO] Explore how different pair of color + fluorescence may result in different price
# Now we just simplify based on UV light intensity
print(df['fluorescence'].unique())
def map_fluorescence(x):
    if x == 'None':
        return 'None'
    elif 'Faint' in x:
        return 'Faint'
    elif 'Medium' in x:
        return 'Medium'
    elif 'Very Strong' in x:
        return 'Very Strong'
    elif 'Strong' in x:
        return 'Strong'
    else:
        raise ValueError('Unexpected value')
df['fluorescence_reduced'] = df['fluorescence'].map(map_fluorescence)
print(df['fluorescence_reduced'].unique())
# Out:
# ['None' 'Medium' 'Faint' 'Strong Blue' 'Medium Blue' 'Strong'
#  'Very Strong' 'Very Strong Blue' 'Medium Yellow']
# ['None' 'Medium' 'Faint' 'Strong' 'Very Strong']

# %%
# parse out measurement columns
measurements = df['measurements'].str.replace(' mm', '').str.split(' x ', expand=True)
measurements = measurements.apply(pd.to_numeric)
measurements.columns = ['length', 'width', 'height']
df = df.join(measurements)

# %%
# preprocess categorical variables
# shapeCode = RD based on condition when we download data from bluenile
# almost all of these variables are ordinal, ie. one category is more preferable than the other category
# we transform these oridnal variables as interval data
cols_cat = ['clarity', 'color',  'cut', 'culet', 'polish', 'symmetry', 'fluorescence_reduced']

# ranking: the bigger the better
ranking = {
    'clarity': ['I2', 'I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF', 'FL'],
    'color': ['K', 'J', 'I', 'H', 'G', 'F', 'E', 'D'],
    'cut': ['Good', 'Very Good', 'Ideal', 'Astor Ideal'], # https://www.bluenile.com/education/diamonds/cut
    'culet': ['Medium', 'Small', 'Very Small', 'Pointed', 'None'],
    'polish': ['Good', 'Very Good', 'Excellent'],
    'symmetry': ['Good', 'Very Good', 'Excellent'],
    'fluorescence_reduced': ['Very Strong', 'Strong', 'Medium', 'Faint', 'None']
}

# ordinal encoding thru pandas
for cc in cols_cat:
    categories = pd.Categorical(df[cc], categories=ranking[cc], ordered=True)
    labels, unique = pd.factorize(categories, sort=True)
    df['cat_'+cc] = labels

# %%
df['hasVisualization'] = df['hasVisualization'].astype(int)

# %%
cols_num = ['carat', 'depth', 'lxwRatio', 'table', 'sellingIndex', 'hasVisualization', 'length', 'width', 'height']

dv = ['price']
iv = cols_num + ['cat_'+cc for cc in cols_cat]

# %%
df_process = df[dv + iv]
df_process.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14705 entries, 0 to 14704
# Data columns (total 17 columns):
# price                       14705 non-null int64
# carat                       14705 non-null float64
# depth                       14705 non-null float64
# lxwRatio                    14705 non-null float64
# table                       14705 non-null float64
# sellingIndex                14705 non-null float64
# hasVisualization            14705 non-null int64
# length                      14705 non-null float64
# width                       14705 non-null float64
# height                      14705 non-null float64
# cat_clarity                 14705 non-null int64
# cat_color                   14705 non-null int64
# cat_cut                     14705 non-null int64
# cat_culet                   14705 non-null int64
# cat_polish                  14705 non-null int64
# cat_symmetry                14705 non-null int64
# cat_fluorescence_reduced    14705 non-null int64
# dtypes: float64(8), int64(9)
# memory usage: 1.9 MB

# %%
df_process.head()
# Out:
#    price  carat  depth  lxwRatio  table  sellingIndex  hasVisualization  \
# price                     -0.001551   -0.000405      0.005302
# carat                      0.143189   -0.004255     -0.062950
# depth                      0.129590    0.050529     -0.168894
# lxwRatio                   0.089575   -0.048686     -0.190646
# table                      0.077584   -0.071933     -0.031963
# sellingIndex               0.118725    0.087345      0.033354
# hasVisualization          -0.103398    0.019190      0.000855
# length                     0.131897   -0.008876     -0.026090
# width                      0.144378   -0.009990     -0.031408
# height                     0.165972    0.013142     -0.071484
# cat_clarity               -0.065369    0.051719      0.054230
# cat_color                 -0.080809   -0.028426     -0.011393
# cat_cut                    0.003232    0.315083      0.492325
# cat_culet                  1.000000    0.074674      0.058628
# cat_polish                 0.074674    1.000000      0.426800
# cat_symmetry               0.058628    0.426800      1.000000
# cat_fluorescence_reduced  -0.046021    0.027583      0.048638
#
#                           cat_fluorescence_reduced
# price                                    -0.028636
# carat                                    -0.185433
# depth                                    -0.090623
# lxwRatio                                 -0.049756
# table                                     0.007231
# sellingIndex                             -0.381190
# hasVisualization                         -0.042906
# length                                   -0.168437
# width                                    -0.171082
# height                                   -0.188311
# cat_clarity                              -0.025889
# cat_color                                -0.031284
# cat_cut                                   0.028508
# cat_culet                                -0.046021
# cat_polish                                0.027583
# cat_symmetry                              0.048638
# cat_fluorescence_reduced                  1.000000

# %%
df_process.to_csv('./data/diamonds_20200602_preprocess.csv', index=False)

# %%
# Split to train and test data
dataset_date = '20200620'

work_dir = '~/WorkDocs/Code/diamonds/data/{}'.format(dataset_date)
raw_path = os.path.join(work_dir, 'preprocess.csv')
df = pd.read_csv(raw_path)
df.head()
# Out:
#    price  carat  depth  lxwRatio  table  sellingIndex  hasVisualization  \
# 0  10001   1.50   59.9      1.01   60.0      0.191319                 1
# 1  10002   1.51   62.7      1.01   57.0      0.333796                 0
# 2  10004   1.05   61.7      1.00   57.0      0.193977                 1
# 3  10005   1.35   62.1      1.01   58.0      0.245716                 1
# 4  10005   1.40   62.7      1.01   58.0      0.561808                 1
#
#    length  width  height  cat_clarity  cat_color  cat_cut  cat_culet  \
# 0    7.45   7.40    4.44            1          3        2          4
# 1    7.32   7.26    4.57            2          3        2          4
# 2    6.52   6.49    4.02            5          6        2          4
# 3    7.07   7.03    4.38            2          4        2          4
# 4    7.06   7.12    4.44            4          3        2          4
#
#    cat_polish  cat_symmetry  cat_fluorescence_reduced
# 0           2             2                         4
# 1           2             2                         4
# 2           2             2                         2
# 3           2             2                         4
# 4           2             2                         4

# %%
SEED = 42
np.random.seed(SEED)

m = df.shape[0]
TRAIN_PERCENT = 0.8

indices = np.random.permutation(m)
cut = int(m * TRAIN_PERCENT)

train, test = df[:cut], df[cut:]
print("Training set shape: {}".format(train.shape))
print("Testing set shape: {}".format(test.shape))
# Out:
# Training set shape: (11764, 17)
# Testing set shape: (2941, 17)

# %%
# Write to csv
train_path = os.path.join(work_dir, 'train.csv'.format(dataset_date))
test_path = os.path.join(work_dir, 'test.csv'.format(dataset_date))

train.to_csv(train_path, header=True, index=False)
test.to_csv(test_path, header=True, index=False)
